# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import ctypes
# %matplotlib inline
matplotlib.style.use('ggplot') # Make the graphs a bit prettier

# %%
lfo = pd.read_csv('./lfo.log')
lfo[0:50].plot()
